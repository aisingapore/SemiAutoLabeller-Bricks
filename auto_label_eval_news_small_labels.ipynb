# %% [markdown]
# # Auto Labeller
# Applied to news dataset to evaluate model performance
# * Uses the full dataset
# * Uses the small label dictionary

# %%
# Standard Libary Imports
import pandas as pd
import numpy as np
import json

from src.toolkit.autolabel import Preprocessor, AutoLabeller, check_labels
from src.toolkit.autolabel import recommend_words, Evaluator

from sklearn.naive_bayes import MultinomialNB

# %%
# file path to text data
text_path = "data/news/news.csv"
labelled_path = "data/news/news_labelled_small_labels.csv"  # INPUT YOUR PREFERED OUTPUT PATH
score_path = "data/news/news_score_small_labels.csv"
labels_path = "data/news/news_labels_small.csv"  # INPUT PATH TO LABELS DICTIONARY

stopwords_path = "data/stopwords.csv"  ## ADJUST IF YOU HAVE CUSTOM STOPWORDS
text_column_name = "content"

news = pd.read_csv(text_path)
data = news[[text_column_name]]

# %%
data.head()
# Out:
#                                              content
# 0  Unions representing workers at Turner   Newall...
# 1  SPACE.com - TORONTO, Canada -- A second\team o...
# 2  AP - A company founded by a chemistry research...
# 3  AP - It's barely dawn when Mike Fitzpatrick st...
# 4  AP - Southern California's smog-fighting agenc...

# %%
corpus = data[text_column_name]

preprocessor = Preprocessor()

# Text Preprocessing
preprocessed_corpus = preprocessor.corpus_preprocess(corpus=corpus, stopwords_path=stopwords_path)

# Replace bigrams
data[text_column_name] = preprocessor.corpus_replace_bigrams(corpus=preprocessed_corpus, min_df=50, max_df=500)
# Out:
# /Users/jinjun/Desktop/aisg/makerspace/bricks/bricks-auto-labeller/env/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# ## Recommended themes and words

# %%
n_words = 20  # CHANGE THE NUMBER OF WORDS RECOMMENDED (IF YOU WANT TO)

# Returns a matrix of recommended words
topic_model, dtm, best_n = recommend_words(corpus) 
topic_model.show_topics(dtm=dtm, best_n=best_n, n_words=n_words)
# Out:
#             0            1                                        2   \
# 0         kill       people                                  baghdad
# 1           gt           lt                                     font
# 2         quot          get                                     call
# 3         high        stock                                    price
# 4       season         team                                  victory
# 5      service     software                                 internet
# 6        lt_gt      lt_href  http_wwwinvestorreuterscomfullquoteaspx
# 7   government       united                                    would
# 8       athens      olympic                                     gold
# 9      israeli  palestinian                                     gaza
# 10     percent         sale                                 research
#
#                                    3            4         5              6   \
# 0                                iraq        least     iraqi           bomb
# 1                              strong        color      size           sans
# 2                                  go         tell    player           look
# 3                           oil_price          oil       low         record
# 4                                lead       sunday     night            run
# 5                            announce     computer    search     technology
# 6   targetstocksquickinfofullquote_gt  new_reuters       inc             co
# 7                                talk      country  european         leader
# 8                               medal     american       men         second
# 9                              israel         army      kill       militant
# 10                             profit        share      rise  quote_profile
#
#            7          8             9               10        11  \
# 0      police      wound           car          attack      city
# 1       arial      serif       verdana       helvetica      face
# 2        word       news     spokesman  merriamwebster      many
# 3       crude     barrel      investor          dollar      rise
# 4      second   saturday          play             cup     final
# 5   microsoft        use        system           phone    launch
# 6     chicago  quarterly      business        earnings    profit
# 7     nuclear      group         state             afp  official
# 8      greece      woman         meter        champion    united
# 9      leader   military          camp         refugee      fire
# 10    quarter  quarterly  thirdquarter           maker       inc
#
#                 12              13           14          15            16  \
# 0     official_say         soldier       injure   insurgent       explode
# 1               br      washington         http        nobr            em
# 2             like         brother    microsoft  dictionary           see
# 3           market          energy  new_reuters      supply          rate
# 4            point           first         last    champion  championship
# 5           mobile            user      release     version       network
# 6          billion           maker  company_say       would           buy
# 7       washington  prime_minister      federal      former         could
# 8         olympics      basketball         time      become         final
# 9   prime_minister       jerusalem        troop  settlement      security
# 10        earnings            post       strong       large       revenue
#
#                    17             18           19
# 0               force          troop        three
# 1   washingtonpostcom            fff     analysis
# 2               death           come          hit
# 3            economic         london      concern
# 4                beat          score        coach
# 5             product       business        music
# 6                drug          stock      percent
# 7            election  international       nation
# 8              silver     gymnastics  competition
# 9              rocket       egyptian       border
# 10                cut            big         loss

# %%
labels = pd.read_csv(labels_path)
labels = check_labels(news[[text_column_name]], labels)
labels.head(5)
# Out:
# olympic is not in the input corpus. It is removed from dictionary
# iraq is not in the input corpus. It is removed from dictionary
#   Business   SciTech    Sports    World
# 0    stock  software       NaN      NaN
# 1    price  internet  champion  soldier

# %%
labels.head(7)
# Out:
#   Business   SciTech    Sports    World
# 0    stock  software       NaN      NaN
# 1    price  internet  champion  soldier

# %%
autoLabeller = AutoLabeller(labels.head(6), corpus, data)
enriched_labels = autoLabeller.train()

enriched_labels  ## Enriched suggested labels
# Out:
#        Business      SciTech      Sports      World
# 0        profit      service     chelsea   military
# 1     oil_price         user      defeat  insurgent
# 2         crude       online      defend      wound
# 3         stock        phone     arsenal     injure
# 4       average        email      streak      iraqi
# 5   new_reuters          web   barcelona   militant
# 6         worry    microsoft       inter      force
# 7           low  application     captain       kill
# 8        energy       search   semifinal     shiite
# 9         sharp          aol        side    baghdad
# 10        share      version    champion     alsadr
# 11       barrel   newsfactor         icc    soldier
# 12         fell     software       final     cleric
# 13         high     provider  tournament      clash
# 14     earnings      network        beat      least
# 15     investor        yahoo      league    suicide
# 16          oil       access        goal      troop
# 17         wall     computer       match       army
# 18         rise     internet     olympic        car
# 19        price      content   brazilian       iraq
# 20      percent   enterprise      trophy       bomb

# %%
mnb = MultinomialNB()
ypred = autoLabeller.apply(mnb, 'content')
ypred.to_csv(labelled_path)

# %%
evaluator = Evaluator()
score = evaluator.evaluate_predictions(news, ypred, labels, split=0.2, random_state=42)
score.to_csv(score_path, index=False)
score
# Out:
#            Business  SciTech  Sports   World
# Precision    0.5829   0.5991  0.6657  0.6712
# Recall       0.6072   0.6366  0.6041  0.6568
# F1-score     0.5948   0.6173  0.6334  0.6640

# %%
evaluator.compare_to_other_models(score, news, labels)
# Out:
#            Automatic Labeling  MLP Neural Network  Gradient Boosted Trees  \
# Precision               0.630               0.804                   0.814
# Recall                  0.626               0.681                   0.454
# F1-score                0.627               0.736                   0.583
#
#            Random Forest
# Precision          0.872
# Recall             0.511
# F1-score           0.644
